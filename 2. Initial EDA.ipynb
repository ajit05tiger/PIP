# %% [markdown]
# ### Initial EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_ne=pd.read_csv("C:/Users/ajit.mishra/Downloads/practice/sample_labeled/VA00000000000022/non_elimination6.csv")
df_urin=pd.read_csv("C:/Users/ajit.mishra/Downloads/practice/sample_labeled/VA00000000000022/urination6.csv")
df_def=pd.read_csv("C:/Users/ajit.mishra/Downloads/practice/sample_labeled/VA00000000000022/defecation6.csv")
df_ne.head()
# Out:
#                         t   lc0   lc1   lc2   lc3  timestamp    sum
# 0         0 days 00:00:00  3678  1147  2481  3877      0.000  11183
# 1  0 days 00:00:00.025000  3653  1148  2523  3884      0.025  11208
# 2  0 days 00:00:00.050000  3660  1155  2558  3874      0.050  11247
# 3  0 days 00:00:00.075000  3645  1156  2566  3838      0.075  11205
# 4  0 days 00:00:00.100000  3638  1158  2584  3822      0.100  11202

# %%
df_ne_json = pd.read_json('C:/Users/ajit.mishra/Downloads/practice/sample_labeled/VA00000000000022/non_elimination6.json',lines=True)
df_urin_json = pd.read_json("C:/Users/ajit.mishra/Downloads/practice/sample_labeled/VA00000000000022/urination6.json",lines=True)
df_def_json = pd.read_json("C:/Users/ajit.mishra/Downloads/practice/sample_labeled/VA00000000000022/defecation6.json",lines=True)
df_ne_json
# Out:
#           Device_ID                                           Event_ID  \
# 0  VA00000000000022  RXZlbnRJbmZvcm1hdGlvbjo2NmY0ZGYzNi0wOGY1LTRhZD...
#
#            Event_start_time                                            Tags  \
# 0 2020-07-15 08:56:23-05:00  [cat in box, synapse_labeled, non_elimination]
#
#    Free_text Name_of_cat  Weight_of_cat  Tare_weight
# 0        NaN    Sparkler           4376          NaN

# %%
#w = Weight of cat 
w_ne = df_ne_json['Weight_of_cat'][0]
w_urin = df_urin_json['Weight_of_cat'][0]
w_def = df_def_json['Weight_of_cat'][0]
w_ne, w_urin, w_def
# Out:
# (4376, 4454, 4348)

# %% [markdown]
# ## 1. Load sensor data

# %% [markdown]
# ### Plot of All sensor for non elimination case

# %%
sns.set(rc = {'figure.figsize':(10,8)})

# %%
X = df_ne.timestamp
  
Y1 = df_ne.lc0
Y2 = df_ne.lc1
Y3 = df_ne.lc2
Y4 = df_ne.lc3
  
# Initialise the subplot function using number of rows and columns
figure, axis = plt.subplots(2, 2)

axis[0, 0].plot(X,Y1)
axis[0, 0].set_title("Sensor 1")

axis[0, 1].plot(X, Y2)
axis[0, 1].set_title("sensor 2")
  
axis[1, 0].plot(X, Y3)
axis[1, 0].set_title("sensor 3")
  
axis[1, 1].plot(X, Y4)
axis[1, 1].set_title("sensor 4")

plt.show()

# %% [markdown]
# ### Plot of all sensor for urination

# %%
X = df_urin.timestamp
  
Y1 = df_urin.lc0
Y2 = df_urin.lc1
Y3 = df_urin.lc2
Y4 = df_urin.lc3
  
# Initialise the subplot function using number of rows and columns
figure, axis = plt.subplots(2, 2)

axis[0, 0].plot(X,Y1)
axis[0, 0].set_title("Sensor 1")

axis[0, 1].plot(X, Y2)
axis[0, 1].set_title("sensor 2")
  
axis[1, 0].plot(X, Y3)
axis[1, 0].set_title("sensor 3")
  
axis[1, 1].plot(X, Y4)
axis[1, 1].set_title("sensor 4")

plt.show()

# %% [markdown]
# ### plot of all sensor for defecation

# %%
X = df_def.timestamp
  
Y1 = df_def.lc0
Y2 = df_def.lc1
Y3 = df_def.lc2
Y4 = df_def.lc3
  
# Initialise the subplot function using number of rows and columns
figure, axis = plt.subplots(2, 2)

axis[0, 0].plot(X,Y1)
axis[0, 0].set_title("Sensor 1")

axis[0, 1].plot(X, Y2)
axis[0, 1].set_title("sensor 2")
  
axis[1, 0].plot(X, Y3)
axis[1, 0].set_title("sensor 3")
  
axis[1, 1].plot(X, Y4)
axis[1, 1].set_title("sensor 4")

plt.show()

# %% [markdown]
# ### Plot of one sensor for all cases

# %%
X1 = df_ne.timestamp
X2 = df_urin.timestamp
X3 = df_def.timestamp

Y1 = df_ne.lc0
Y2 = df_urin.lc0
Y3 = df_def.lc0

figure, axis = plt.subplots(3,1, figsize=(7,9))

axis[0].plot(X1,Y1)
axis[0].set_title("non elimination")

axis[1].plot(X2, Y2)
axis[1].set_title("urination")

axis[2].plot(X3, Y3)
axis[2].set_title("defecation")

plt.show()

# %%
df_urin.head()
# Out:
#                         t   lc0   lc1   lc2   lc3  timestamp    sum
# 0         0 days 00:00:00  3225  2683  2439  4023      0.000  12370
# 1  0 days 00:00:00.025000  3093  2669  2492  4344      0.025  12598
# 2  0 days 00:00:00.050000  3276  2661  2421  4358      0.050  12716
# 3  0 days 00:00:00.075000  3269  2724  2421  4332      0.075  12746
# 4  0 days 00:00:00.100000  3285  2759  2424  4124      0.100  12592

# %%
df_ne.drop(['t'],axis=1,inplace=True)
df_urin.drop(['t'],axis=1,inplace=True)
df_def.drop(['t'],axis=1,inplace=True)
df_ne
# Out:
#        lc0   lc1   lc2   lc3  timestamp    sum
# 0     3678  1147  2481  3877      0.000  11183
# 1     3653  1148  2523  3884      0.025  11208
# 2     3660  1155  2558  3874      0.050  11247
# 3     3645  1156  2566  3838      0.075  11205
# 4     3638  1158  2584  3822      0.100  11202
# ...    ...   ...   ...   ...        ...    ...
# 3931  3164   810   714  2288     98.275   6976
# 3932  3163   809   713  2288     98.300   6973
# 3933  3165   809   713  2288     98.325   6975
# 3934  3165   810   714  2288     98.350   6977
# 3935  3163   809   714  2289     98.375   6975
#
# [3936 rows x 6 columns]

# %% [markdown]
# ## 2. Change in load

# %%
df_ne['diff_lc0']= df_ne['lc0'].diff()
df_ne['diff_lc1']= df_ne['lc1'].diff()
df_ne['diff_lc2']= df_ne['lc2'].diff()
df_ne['diff_lc3']= df_ne['lc3'].diff()
df_ne.head()
# Out:
#     lc0   lc1   lc2   lc3  timestamp    sum  diff_lc0  diff_lc1  diff_lc2  \
# 0  3678  1147  2481  3877      0.000  11183       NaN       NaN       NaN
# 1  3653  1148  2523  3884      0.025  11208     -25.0       1.0      42.0
# 2  3660  1155  2558  3874      0.050  11247       7.0       7.0      35.0
# 3  3645  1156  2566  3838      0.075  11205     -15.0       1.0       8.0
# 4  3638  1158  2584  3822      0.100  11202      -7.0       2.0      18.0
#
#    diff_lc3
# 0       NaN
# 1       7.0
# 2     -10.0
# 3     -36.0
# 4     -16.0

# %%
df_urin['diff_lc0']= df_urin['lc0'].diff()
df_urin['diff_lc1']= df_urin['lc1'].diff()
df_urin['diff_lc2']= df_urin['lc2'].diff()
df_urin['diff_lc3']= df_urin['lc3'].diff()
# df_urin.head()

# %%
df_def['diff_lc0']= df_def['lc0'].diff()
df_def['diff_lc1']= df_def['lc1'].diff()
df_def['diff_lc2']= df_def['lc2'].diff()
df_def['diff_lc3']= df_def['lc3'].diff()
# df_def.head()

# %% [markdown]
# ### Visualisation of change in load

# %% [markdown]
# ### For Non elemination

# %%
X = df_ne.timestamp
  
Y1 = df_ne.diff_lc0
Y2 = df_ne.diff_lc1
Y3 = df_ne.diff_lc2
Y4 = df_ne.diff_lc3
  
# Initialise the subplot function using number of rows and columns
figure, axis = plt.subplots(2, 2)

axis[0, 0].plot(X,Y1)
axis[0, 0].set_title("Sensor 1")

axis[0, 1].plot(X, Y2)
axis[0, 1].set_title("sensor 2")
  
axis[1, 0].plot(X, Y3)
axis[1, 0].set_title("sensor 3")
  
axis[1, 1].plot(X, Y4)
axis[1, 1].set_title("sensor 4")

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.heatmap(df_ne.corr(), annot=True, linewidths=.5, ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### For Urination

# %%
X = df_urin.timestamp
  
Y1 = df_urin.diff_lc0
Y2 = df_urin.diff_lc1
Y3 = df_urin.diff_lc2
Y4 = df_urin.diff_lc3
  
# Initialise the subplot function using number of rows and columns
figure, axis = plt.subplots(2, 2)

axis[0, 0].plot(X,Y1)
axis[0, 0].set_title("Sensor 1")

axis[0, 1].plot(X, Y2)
axis[0, 1].set_title("sensor 2")
  
axis[1, 0].plot(X, Y3)
axis[1, 0].set_title("sensor 3")
  
axis[1, 1].plot(X, Y4)
axis[1, 1].set_title("sensor 4")

plt.show()

# %% [markdown]
# #### Here lesser loads is representing the cat is urinating and the time difference is indicating the cat is urinating in this time period. and higher loads before lesser loads are representing the cat is digging up and the higher loads after the lesser loads are representing the cat is filling his urin

# %% [markdown]
# ### For Defecation

# %%
X = df_def.timestamp
  
Y1 = df_def.diff_lc0
Y2 = df_def.diff_lc1
Y3 = df_def.diff_lc2
Y4 = df_def.diff_lc3
  
# Initialise the subplot function using number of rows and columns
figure, axis = plt.subplots(2, 2)

axis[0, 0].plot(X,Y1)
axis[0, 0].set_title("Sensor 1")

axis[0, 1].plot(X, Y2)
axis[0, 1].set_title("sensor 2")
  
axis[1, 0].plot(X, Y3)
axis[1, 0].set_title("sensor 3")
  
axis[1, 1].plot(X, Y4)
axis[1, 1].set_title("sensor 4")

plt.show()

# %% [markdown]
# #### Here lesser loads is representing the cat is defecating and the time difference is indicating the cat is defecating in this time period. and higher loads before lesser loads are representing the cat is digging up and the higher loads after the lesser loads are representing the cat is filling his defecate

# %% [markdown]
# ### For all cases

# %%
X1 = df_ne.timestamp
X2 = df_urin.timestamp
X3 = df_def.timestamp

Y1 = df_ne.diff_lc0
Y2 = df_urin.diff_lc0
Y3 = df_def.diff_lc0

figure, axis = plt.subplots(3,1, figsize=(10,10))

axis[0].plot(X1,Y1)
axis[0].set_title("non extraction")

axis[1].plot(X2, Y2)
axis[1].set_title("urination")

axis[2].plot(X3, Y3)
axis[2].set_title("defecation")

plt.show()

# %% [markdown]
# ## 3. Acceleration using change in load

# %%
# Force = Mass * Acceleration
# acceleration (a) = Force / Weight of cat (w)

df_ne['acc_lc0']= df_ne['diff_lc0'].apply(lambda x: x/w_ne)
df_ne['acc_lc1']= df_ne['diff_lc1'].apply(lambda x: x/w_ne)
df_ne['acc_lc2']= df_ne['diff_lc2'].apply(lambda x: x/w_ne)
df_ne['acc_lc3']= df_ne['diff_lc3'].apply(lambda x: x/w_ne)
df_ne.head()
# Out:
#     lc0   lc1   lc2  lc3  timestamp   sum  diff_lc0  diff_lc1  diff_lc2  \
# 0  1849  1269  4344  -42      0.000  7420       NaN       NaN       NaN
# 1  1847  1272  4340  -45      0.025  7414      -2.0       3.0      -4.0
# 2  1845  1271  4342  -38      0.050  7420      -2.0      -1.0       2.0
# 3  1845  1272  4341  -42      0.075  7416       0.0       1.0      -1.0
# 4  1844  1272  4342  -40      0.100  7418      -1.0       0.0       1.0
#
#    diff_lc3   acc_lc0   acc_lc1   acc_lc2   acc_lc3
# 0       NaN       NaN       NaN       NaN       NaN
# 1      -3.0 -0.000321  0.000482 -0.000643 -0.000482
# 2       7.0 -0.000321 -0.000161  0.000321  0.001125
# 3      -4.0  0.000000  0.000161 -0.000161 -0.000643
# 4       2.0 -0.000161  0.000000  0.000161  0.000321

# %%
df_urin['acc_lc0']= df_urin['diff_lc0'].apply(lambda x: x/w_urin)
df_urin['acc_lc1']= df_urin['diff_lc1'].apply(lambda x: x/w_urin)
df_urin['acc_lc2']= df_urin['diff_lc2'].apply(lambda x: x/w_urin)
df_urin['acc_lc3']= df_urin['diff_lc3'].apply(lambda x: x/w_urin)

# %%
df_def['acc_lc0']= df_def['diff_lc0'].apply(lambda x: x/w_def)
df_def['acc_lc1']= df_def['diff_lc1'].apply(lambda x: x/w_def)
df_def['acc_lc2']= df_def['diff_lc2'].apply(lambda x: x/w_def)
df_def['acc_lc3']= df_def['diff_lc3'].apply(lambda x: x/w_def)

# %%
X1 = df_ne.timestamp
X2 = df_urin.timestamp
X3 = df_def.timestamp

Y1 = df_ne.acc_lc0
Y2 = df_urin.acc_lc0
Y3 = df_def.acc_lc0

figure, axis = plt.subplots(3,1, figsize=(10,10))

axis[0].plot(X1,Y1)
axis[0].set_title("non extraction")

axis[1].plot(X2, Y2)
axis[1].set_title("urination")

axis[2].plot(X3, Y3)
axis[2].set_title("defecation")

plt.show()

# %% [markdown]
# ## 4. Velocity

# %%
df_ne['velo_lc0'] = 0
df_ne['velo_lc1'] = 0
df_ne['velo_lc2'] = 0
df_ne['velo_lc3'] = 0

# %%
df_ne['velo_lc0'] = 0
df_ne['velo_lc1'] = 0
df_ne['velo_lc2'] = 0
df_ne['velo_lc3'] = 0
for i in range (1,len(df_ne)):
    df_ne['velo_lc0'][i]=(df_ne['acc_lc0'][i]*0.025)+(df_ne['velo_lc0'][i-1])
    df_ne['velo_lc1'][i]=(df_ne['acc_lc1'][i]*0.025)+(df_ne['velo_lc1'][i-1])
    df_ne['velo_lc2'][i]=(df_ne['acc_lc2'][i]*0.025)+(df_ne['velo_lc2'][i-1])
    df_ne['velo_lc3'][i]=(df_ne['acc_lc3'][i]*0.025)+(df_ne['velo_lc3'][i-1])
    
df_urin['velo_lc0'] = 0
df_urin['velo_lc1'] = 0
df_urin['velo_lc2'] = 0
df_urin['velo_lc3'] = 0
for i in range (1,len(df_urin)):
    df_urin['velo_lc0'][i]=(df_urin['acc_lc0'][i]*0.025)+(df_urin['velo_lc0'][i-1])
    df_urin['velo_lc1'][i]=(df_urin['acc_lc1'][i]*0.025)+(df_urin['velo_lc1'][i-1])
    df_urin['velo_lc2'][i]=(df_urin['acc_lc2'][i]*0.025)+(df_urin['velo_lc2'][i-1])
    df_urin['velo_lc3'][i]=(df_urin['acc_lc3'][i]*0.025)+(df_urin['velo_lc3'][i-1])
    
df_def['velo_lc0'] = 0
df_def['velo_lc1'] = 0
df_def['velo_lc2'] = 0
df_def['velo_lc3'] = 0
for i in range (1,len(df_def)):
    df_def['velo_lc0'][i]=(df_def['acc_lc0'][i]*0.025)+(df_def['velo_lc0'][i-1])
    df_def['velo_lc1'][i]=(df_def['acc_lc1'][i]*0.025)+(df_def['velo_lc1'][i-1])
    df_def['velo_lc2'][i]=(df_def['acc_lc2'][i]*0.025)+(df_def['velo_lc2'][i-1])
    df_def['velo_lc3'][i]=(df_def['acc_lc3'][i]*0.025)+(df_def['velo_lc3'][i-1])
# Out:
# C:\Users\ajit.mishra\AppData\Local\Temp\ipykernel_16936\1720823311.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ne['velo_lc0'][i]=(df_ne['acc_lc0'][i]*0.025)+(df_ne['velo_lc0'][i-1])
# C:\Users\ajit.mishra\AppData\Local\Temp\ipykernel_16936\1720823311.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ne['velo_lc1'][i]=(df_ne['acc_lc1'][i]*0.025)+(df_ne['velo_lc1'][i-1])
# C:\Users\ajit.mishra\AppData\Local\Temp\ipykernel_16936\1720823311.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ne['velo_lc2'][i]=(df_ne['acc_lc2'][i]*0.025)+(df_ne['velo_lc2'][i-1])
# C:\Users\ajit.mishra\AppData\Local\Temp\ipykernel_16936\1720823311.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ne['velo_lc3'][i]=(df_ne['acc_lc3'][i]*0.025)+(df_ne['velo_lc3'][i-1])
# C:\Users\ajit.mishra\AppData\Local\Temp\ipykernel_16936\1720823311.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_urin['velo_lc0'][i]=(df_urin['acc_lc0'][i]*0.025)+(df_urin['velo_lc0'][i-1])
# C:\Users\ajit.mishra\AppData\Local\Temp\ipykernel_16936\1720823311.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_urin['velo_lc1'][i]=(df_urin['acc_lc1'][i]*0.025)+(df_urin['velo_lc1'][i-1])
# C:\Users\ajit.mishra\AppData\Local\Temp\ipykernel_16936\1720823311.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_urin['velo_lc2'][i]=(df_urin['acc_lc2'][i]*0.025)+(df_urin['velo_lc2'][i-1])
# C:\Users\ajit.mishra\AppData\Local\Temp\ipykernel_16936\1720823311.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_urin['velo_lc3'][i]=(df_urin['acc_lc3'][i]*0.025)+(df_urin['velo_lc3'][i-1])
# C:\Users\ajit.mishra\AppData\Local\Temp\ipykernel_16936\1720823311.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_def['velo_lc0'][i]=(df_def['acc_lc0'][i]*0.025)+(df_def['velo_lc0'][i-1])
# C:\Users\ajit.mishra\AppData\Local\Temp\ipykernel_16936\1720823311.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_def['velo_lc1'][i]=(df_def['acc_lc1'][i]*0.025)+(df_def['velo_lc1'][i-1])
# C:\Users\ajit.mishra\AppData\Local\Temp\ipykernel_16936\1720823311.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_def['velo_lc2'][i]=(df_def['acc_lc2'][i]*0.025)+(df_def['velo_lc2'][i-1])
# C:\Users\ajit.mishra\AppData\Local\Temp\ipykernel_16936\1720823311.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_def['velo_lc3'][i]=(df_def['acc_lc3'][i]*0.025)+(df_def['velo_lc3'][i-1])

# %%
X1 = df_ne.timestamp
X2 = df_urin.timestamp
X3 = df_def.timestamp

Y1 = df_ne.velo_lc0
Y2 = df_urin.velo_lc0
Y3 = df_def.velo_lc0

figure, axis = plt.subplots(3,1, figsize=(10,10))

axis[0].plot(X1,Y1)
axis[0].set_title("non extraction")

axis[1].plot(X2, Y2)
axis[1].set_title("urination")

axis[2].plot(X3, Y3)
axis[2].set_title("defecation")

plt.show()

# %% [markdown]
# ## 5. Energy

# %%
# e=1/2(m*v^2)
# m=w/9.81
#e = 0.5(w*v**2)

# %%
df_ne['enr_lc0']= df_ne['velo_lc0'].apply(lambda x: 0.5*w_ne*(x**2))
df_ne['enr_lc1']= df_ne['velo_lc1'].apply(lambda x: 0.5*w_ne*(x**2))
df_ne['enr_lc2']= df_ne['velo_lc2'].apply(lambda x: 0.5*w_ne*(x**2))
df_ne['enr_lc3']= df_ne['velo_lc3'].apply(lambda x: 0.5*w_ne*(x**2))
# df_ne.head()

df_urin['enr_lc0']= df_urin['velo_lc0'].apply(lambda x: 0.5*w_urin*(x**2))
df_urin['enr_lc1']= df_urin['velo_lc1'].apply(lambda x: 0.5*w_urin*(x**2))
df_urin['enr_lc2']= df_urin['velo_lc2'].apply(lambda x: 0.5*w_urin*(x**2))
df_urin['enr_lc3']= df_urin['velo_lc3'].apply(lambda x: 0.5*w_urin*(x**2))
# df_urin.head()

df_def['enr_lc0']= df_def['velo_lc0'].apply(lambda x: 0.5*w_def*(x**2))
df_def['enr_lc1']= df_def['velo_lc1'].apply(lambda x: 0.5*w_def*(x**2))
df_def['enr_lc2']= df_def['velo_lc2'].apply(lambda x: 0.5*w_def*(x**2))
df_def['enr_lc3']= df_def['velo_lc3'].apply(lambda x: 0.5*w_def*(x**2))
# df_def.head()

# %%
X1 = df_ne.timestamp
X2 = df_urin.timestamp
X3 = df_def.timestamp

Y1 = df_ne.enr_lc0
Y2 = df_urin.enr_lc0
Y3 = df_def.enr_lc0

figure, axis = plt.subplots(3,1, figsize=(10,10))

axis[0].plot(X1,Y1)
axis[0].set_title("non extraction")

axis[1].plot(X2, Y2)
axis[1].set_title("urination")

axis[2].plot(X3, Y3)
axis[2].set_title("defecation")

plt.show()

# %% [markdown]
# ## 6. Power

# %%
# Power  = Force * Velocity

# %%
df_ne['power_lc0']= df_ne['velo_lc0']*df_ne['diff_lc0']
df_ne['power_lc1']= df_ne['velo_lc1']*df_ne['diff_lc1']
df_ne['power_lc2']= df_ne['velo_lc2']*df_ne['diff_lc2']
df_ne['power_lc3']= df_ne['velo_lc3']*df_ne['diff_lc3']
# df_ne.head()

df_urin['power_lc0']= df_urin['velo_lc0']*df_urin['diff_lc0']
df_urin['power_lc1']= df_urin['velo_lc1']*df_urin['diff_lc1']
df_urin['power_lc2']= df_urin['velo_lc2']*df_urin['diff_lc2']
df_urin['power_lc3']= df_urin['velo_lc3']*df_urin['diff_lc3']

df_def['power_lc0']= df_def['velo_lc0']*df_def['diff_lc0']
df_def['power_lc1']= df_def['velo_lc1']*df_def['diff_lc1']
df_def['power_lc2']= df_def['velo_lc2']*df_def['diff_lc2']
df_def['power_lc3']= df_def['velo_lc3']*df_def['diff_lc3']

# %%
X1 = df_ne.timestamp
X2 = df_urin.timestamp
X3 = df_def.timestamp

Y1 = df_ne.power_lc0
Y2 = df_urin.power_lc0
Y3 = df_def.power_lc0

figure, axis = plt.subplots(3,1, figsize=(10,10))

axis[0].plot(X1,Y1)
axis[0].set_title("non extraction")

axis[1].plot(X2, Y2)
axis[1].set_title("urination")

axis[2].plot(X3, Y3)
axis[2].set_title("defecation")

plt.show()

# %% [markdown]
# ## 7. Momentum

# %%
# Momentum = Mass * Velocity

# %%
df_ne['mom_lc0']=w_ne*df_ne['velo_lc0']
df_ne['mom_lc1']=w_ne*df_ne['velo_lc1']
df_ne['mom_lc2']=w_ne*df_ne['velo_lc2']
df_ne['mom_lc3']=w_ne*df_ne['velo_lc3']
# df_ne

df_urin['mom_lc0']=w_urin*df_ne['velo_lc0']
df_urin['mom_lc1']=w_urin*df_ne['velo_lc1']
df_urin['mom_lc2']=w_urin*df_ne['velo_lc2']
df_urin['mom_lc3']=w_urin*df_ne['velo_lc3']

df_def['mom_lc0']=w_def*df_ne['velo_lc0']
df_def['mom_lc1']=w_def*df_ne['velo_lc1']
df_def['mom_lc2']=w_def*df_ne['velo_lc2']
df_def['mom_lc3']=w_def*df_ne['velo_lc3']

# %%
X1 = df_ne.timestamp
X2 = df_urin.timestamp
X3 = df_def.timestamp

Y1 = df_ne.mom_lc0
Y2 = df_urin.mom_lc0
Y3 = df_def.mom_lc0

figure, axis = plt.subplots(3,1, figsize=(10,10))

axis[0].plot(X1,Y1)
axis[0].set_title("non extraction")

axis[1].plot(X2, Y2)
axis[1].set_title("urination")

axis[2].plot(X3, Y3)
axis[2].set_title("defecation")

plt.show()

# %% [markdown]
# ### Multiple picture together

# %%
def multiple_image():
    activity=input("Enter activity (defecation / urination / non_elimination): ")
    file_no=input("Enter file number (017/048/192): ")
    figure, axis = plt.subplots(3,4, figsize=(18,9.5))
    for n in range (1,13):
        df = pd.read_csv("D:\Ajit\pip\sample_labeled6/VA00000000000"+file_no+"/"+activity+str(n)+".csv")
        x=df.timestamp
        y=df.diff_load_sum

        if n%12==1:
            axis[0,0].plot(x,y)
            axis[0,0].set_title(file_no+"_"+activity+"_"+(str(n)))

        elif n%12==2:
            axis[1,0].plot(x,y)
            axis[1,0].set_title(file_no+"_"+activity+"_"+(str(n)))

        elif n%12==3:
            axis[2,0].plot(x,y)
            axis[2,0].set_title(file_no+"_"+activity+"_"+(str(n)))

        elif n%12==4:
            axis[0,1].plot(x,y)
            axis[0,1].set_title(file_no+"_"+activity+"_"+(str(n)))

        elif n%12==5:
            axis[1,1].plot(x,y)
            axis[1,1].set_title(file_no+"_"+activity+"_"+(str(n)))

        elif n%12==6:
            axis[2,1].plot(x,y)
            axis[2,1].set_title(file_no+"_"+activity+"_"+(str(n)))

        elif n%12==7:
            axis[0,2].plot(x,y)
            axis[0,2].set_title(file_no+"_"+activity+"_"+(str(n)))

        elif n%12==8:
            axis[1,2].plot(x,y)
            axis[1,2].set_title(file_no+"_"+activity+"_"+(str(n)))

        elif n%12==9:
            axis[2,2].plot(x,y)
            axis[2,2].set_title(file_no+"_"+activity+"_"+(str(n)))

        elif n%12==10:
            axis[0,3].plot(x,y)
            axis[0,3].set_title(file_no+"_"+activity+"_"+(str(n)))

        elif n%12==11:
            axis[1,3].plot(x,y)
            axis[1,3].set_title(file_no+"_"+activity+"_"+(str(n)))

        elif n%12==0:
            axis[2,3].plot(x,y)
            axis[2,3].set_title(file_no+"_"+activity+"_"+(str(n)))

    # plt.savefig('load_'+file_no+'_'+activity+'1.jpg')

    plt.show()

# %%
multiple_image()
# Out:
# Enter activity (defecation / urination / non_elimination): non_elimination
# Enter file number (017/048/192): 038

# %%
multiple_image()
# Out:
# Enter activity (defecation / urination / non_elimination): urination
# Enter file number (017/048/192): 038

# %%
multiple_image()
# Out:
# Enter activity (defecation / urination / non_elimination): defecation
# Enter file number (017/048/192): 038

# %%
#### Here lesser loads is representing the cat is defecating and larger and the time difference is indicating the cat is defecating in this time period. and higher loads before lesser loads are representing the cat is digging up and the higher loads after the lesser loads are representing the cat is filling his defecate
